# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import cv2
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
# 2 painters simple convnet

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(412, 550, 3) 
)
conv_base.trainable = False

def get_features_and_labels(features, labels):
    print(features.shape)
    all_features = []
    for feature in features:
        feature = feature.reshape(-1, 412, 550, 3)
        preprocessed_image = keras.applications.vgg16.preprocess_input(feature)
        features = conv_base.predict(preprocessed_image)
        all_features.append(features)
    return np.concatenate(all_features), labels
        

def create_simpleconvnet():
    inputs = keras.Input(shape=(12, 17, 512))
    x = layers.Flatten()(inputs)
    x = layers.Dense(256)(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Flatten()(x)
    outputs = layers.Dense(2, activation='sigmoid')(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    
    model.compile(loss="categorical_crossentropy",optimizer='adam', metrics=["accuracy"])

    model.summary()
    
    return model

# %%
model = create_simpleconvnet()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_34 (InputLayer)       [(None, 12, 17, 512)]     0
#
#  flatten_11 (Flatten)        (None, 104448)            0
#
#  dense_11 (Dense)            (None, 256)               26738944
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  flatten_12 (Flatten)        (None, 256)               0
#
#  dense_12 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 26739458 (102.00 MB)
# Trainable params: 26739458 (102.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#mix arrays per n elements

def mix(elements1:[], elements2:[], n=5):
    objects_set = []
    labels_set = []
    i = 0
    while i < len(elements1) and i < len(elements2):
            objects_set.append(np.reshape(elements1[i], (412, 550, 3)))
            labels_set.append([1, 0])
    
            objects_set.append(np.reshape(elements2[i], (412, 550, 3)))
            labels_set.append([0, 1])
            
            i+=1
            
    return np.array(objects_set), np.array(labels_set)

# %%
cwd = os.getcwd()
dir_train_rubens = "dataset/validation/rubens"
dir_train_picasso= "dataset/validation/picasso"
dir_validation_rubens = "dataset/test/rubens"
dir_validation_picasso= "dataset/test/picasso"
file_train_rubens = os.listdir(dir_train_rubens)
file_validation_rubens = os.listdir(dir_validation_rubens)
file_train_picasso = os.listdir(dir_train_picasso)
file_validation_picasso = os.listdir(dir_validation_picasso)

train_rubens =[Image.open(os.path.join(dir_train_rubens, file)) for file in file_train_rubens]
train_picasso =[Image.open(os.path.join(dir_train_picasso, file)) for file in file_train_picasso]
validation_rubens = [Image.open(os.path.join(dir_validation_rubens, file)) for file in file_validation_rubens]
validation_picasso = [Image.open(os.path.join(dir_validation_picasso, file)) for file in file_validation_picasso]

train_set, train_labels = mix(train_rubens, train_picasso)
validation_set, validation_labels = mix(validation_rubens, validation_picasso)

train_set = train_set.reshape(len(train_set), 412, 550, 3)
validation_set = validation_set.reshape(len(validation_set), 412, 550, 3)

train_set, train_labels = get_features_and_labels(train_set, train_labels)
validation_set, n = get_features_and_labels(validation_set, validation_labels)

print(len(validation_set), len(n))

callbacks = [keras.callbacks.ModelCheckpoint(filepath="convnet_pretrained.keras")]

history = model.fit(train_set, train_labels, validation_data=(validation_set, n), epochs=30, batch_size=60, callbacks=callbacks)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')

plt.show()
# Out:
# (170, 412, 550, 3)
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 1s 506ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 474ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 467ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 462ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 463ms/step
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 383ms/step
# (200, 412, 550, 3)
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 493ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 458ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 468ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 429ms/step
# 200 200
# Epoch 1/30
# 3/3 [==============================] - 2s 625ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 70.9904 - val_accuracy: 0.9200
# Epoch 2/30
# 3/3 [==============================] - 1s 581ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 67.9523 - val_accuracy: 0.9200
# Epoch 3/30
# 3/3 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 65.7636 - val_accuracy: 0.9250
# Epoch 4/30
# 3/3 [==============================] - 1s 578ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 64.2679 - val_accuracy: 0.9300
# Epoch 5/30
# 3/3 [==============================] - 1s 580ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 63.3567 - val_accuracy: 0.9400
# Epoch 6/30
# 3/3 [==============================] - 1s 570ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 62.7630 - val_accuracy: 0.9400
# Epoch 7/30
# 3/3 [==============================] - 1s 572ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 62.3125 - val_accuracy: 0.9400
# Epoch 8/30
# 3/3 [==============================] - 1s 583ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.9709 - val_accuracy: 0.9400
# Epoch 9/30
# 3/3 [==============================] - 1s 574ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.7125 - val_accuracy: 0.9400
# Epoch 10/30
# 3/3 [==============================] - 1s 577ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.5173 - val_accuracy: 0.9400
# Epoch 11/30
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.3703 - val_accuracy: 0.9400
# Epoch 12/30
# 3/3 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.2597 - val_accuracy: 0.9400
# Epoch 13/30
# 3/3 [==============================] - 1s 580ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.1767 - val_accuracy: 0.9400
# Epoch 14/30
# 3/3 [==============================] - 1s 585ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.1144 - val_accuracy: 0.9400
# Epoch 15/30
# 3/3 [==============================] - 1s 581ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.0678 - val_accuracy: 0.9400
# Epoch 16/30
# 3/3 [==============================] - 1s 577ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.0330 - val_accuracy: 0.9400
# Epoch 17/30
# 3/3 [==============================] - 1s 572ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 61.0069 - val_accuracy: 0.9400
# Epoch 18/30
# 3/3 [==============================] - 1s 581ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9875 - val_accuracy: 0.9400
# Epoch 19/30
# 3/3 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9730 - val_accuracy: 0.9400
# Epoch 20/30
# 3/3 [==============================] - 1s 572ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9622 - val_accuracy: 0.9400
# Epoch 21/30
# 3/3 [==============================] - 1s 580ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9542 - val_accuracy: 0.9400
# Epoch 22/30
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9482 - val_accuracy: 0.9400
# Epoch 23/30
# 3/3 [==============================] - 1s 603ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9438 - val_accuracy: 0.9400
# Epoch 24/30
# 3/3 [==============================] - 1s 591ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9405 - val_accuracy: 0.9400
# Epoch 25/30
# 3/3 [==============================] - 1s 580ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9380 - val_accuracy: 0.9400
# Epoch 26/30
# 3/3 [==============================] - 1s 572ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9362 - val_accuracy: 0.9400
# Epoch 27/30
# 3/3 [==============================] - 1s 582ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9349 - val_accuracy: 0.9400
# Epoch 28/30
# 3/3 [==============================] - 1s 578ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9339 - val_accuracy: 0.9400
# Epoch 29/30
# 3/3 [==============================] - 1s 576ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9332 - val_accuracy: 0.9400
# Epoch 30/30
# 3/3 [==============================] - 1s 587ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 60.9326 - val_accuracy: 0.9400

# %%
from sklearn.preprocessing import MinMaxScaler

model = keras.models.load_model('convnet_pretrained.keras')

layer_output = []
layer_names = []
for layer in model.layers:
    if isinstance(layer, (layers.Conv2D, layers.MaxPooling2D)):
        layer_output.append(layer.output)
        layer_names.append(layer.name)
        
activation_model = keras.Model(inputs=model.input, outputs=layer_output)

img_path = Image.open("dataset/test/picasso/1468.jpg")
img_path = np.reshape(img_path, (412, 550, 3))
img_path = np.expand_dims(img_path, axis=0)

img_path , _ = get_features_and_labels(img_path, None)

activations = activation_model.predict(img_path)

images_per_row = 4
for layer_name, layer_activations in zip(layer_names, activations):
    n_features = layer_activations.shape[-1]
    height = layer_activations.shape[2]
    width = layer_activations.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros(((width + 1) * n_cols - 1, images_per_row * (height + 1) - 1))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            chanal_index = col * images_per_row + row
            channel_img = layer_activations[0, :, :, chanal_index].copy()
            
            if channel_img.sum() != 0:
                channel_img -= channel_img.mean()
                channel_img /= channel_img.std()
                channel_img *= 64
                channel_img += 128

            channel_img = np.clip(channel_img, 0, 255).astype(np.uint8)

            display_grid[
                col * (width + 1) : (col + 1) * width + col, 
                row * (height + 1) : (row + 1) * height + row
            ] = channel_img

    scale_width = 1.0 / width
    scale_height = 1.0 / height
    plt.figure(figsize=(scale_height * display_grid.shape[1],scale_width * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    # plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# (1, 412, 550, 3)
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 17ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[102], line 20
#      16 img_path = np.expand_dims(img_path, axis=0)
#      18 img_path , _ = get_features_and_labels(img_path, None)
# ---> 20 activations = activation_model.predict(img_path)
#      22 images_per_row = 4
#      23 for layer_name, layer_activations in zip(layer_names, activations):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:680, in sync_to_numpy_or_python_type(tensors)
#     677 if isinstance(tensors, tf.distribute.experimental.coordinator.RemoteValue):
#     678     tensors = tensors.fetch()
#     679 if isinstance(tensors, list) and isinstance(
# --> 680     tensors[0], tf.distribute.experimental.coordinator.RemoteValue
#     681 ):
#     682     tensors = tf.nest.map_structure(lambda t: t.fetch(), tensors)
#     684 def _to_single_numpy_or_python_type(t):
#     685     # Don't turn ragged or sparse tensors to NumPy.
#
# IndexError: list index out of range

# %%
cwd = os.getcwd()
dir_test_rubens = "dataset/test/rubens"
dir_test_picasso= "dataset/test/picasso"
file_test_rubens = os.listdir(dir_test_rubens)
file_test_picasso = os.listdir(dir_test_picasso)

test_rubens = [Image.open(os.path.join(dir_test_rubens, file)) for file in file_validation_rubens]
test_picasso = [Image.open(os.path.join(dir_test_picasso, file)) for file in file_test_picasso]

test_set, test_labels = mix(test_rubens, test_picasso)

test_set = test_set.reshape(len(test_set), 412, 550, 3)

test_model = keras.models.load_model('convnet_from_scratch.keras')
test_loss, test_acc = test_model.evaluate(test_set, test_labels)
print('Test loss:', test_loss)
# Out:
# 7/7 [==============================] - 4s 481ms/step - loss: 1.5124 - accuracy: 0.7050
# Test loss: 1.512364149093628
